# %% [markdown]
# # POC-English-Amb+disAmb test `2018-07-27`
#
# New (2018-07-05) Grammar Tester, server `94.130.238.118`
# Link Grammar dictionary words `word@a, word@b` renamed ⇒ `word.a, word.b`
# **Data and directory names updated 2018-07-17**, not compatible with previous data
#
# Each line is calculated 1x, parsing metrics tested 1x for each calculation.
# The calculation table is shared as 'short_table.txt' in data folder
# [http://langlearn.singularitynet.io/data/clustering_2018/POC-English-Amb+disAmb-2018-07-27/](http://langlearn.singularitynet.io/data/clustering_2018/POC-English-Amb+disAmb-2018-07-27/)
# This notebook is shared as static html via
# [http://langlearn.singularitynet.io/data/clustering_2018/html/POC-English-Amb+disAmb-2018-07-27.html](http://langlearn.singularitynet.io/data/clustering_2018/html/POC-English-Amb+disAmb-2018-07-27.html)
# A multi-run version of this test is shared via
# [http://langlearn.singularitynet.io/data/clustering_2018/html/POC-English-Amb+disAmb-2018-07-27-multi.html](http://langlearn.singularitynet.io/data/clustering_2018/html/POC-English-Amb+disAmb-2018-07-27-multi.html)

# %% [markdown]
# ## Basic settings

# %%
import os, sys, time
from IPython.display import display
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path: 
    sys.path.append(module_path)
grammar_learner_path = module_path + '/src/grammar_learner/'
if os.path.exists(grammar_learner_path) and grammar_learner_path not in sys.path: 
    sys.path.append(grammar_learner_path)
from utl import UTC
from read_files import check_dir
from widgets import html_table
from pqa_table import table_damb
tmpath = module_path + '/tmp/'
if check_dir(tmpath, True, 'none'):
    table = []
    long_table = []
    header = ['Line','Corpus','Parsing','LW','"."','Generalization','Space','Rules','PA','PQ']
    start = time.time()
    print(UTC(), ':: module_path =', module_path)
else: print(UTC(), ':: could not create temporary files directory', tmpath)
# Out:
# 2018-07-27 15:23:36 UTC :: module_path = /home/obaskov/language-learning

# %% [markdown]
# ## Grammar Learner corpus-specific parameters

# %%
corpus = 'POC-English-Amb'
out_dir = module_path + '/output/'+ corpus + '-' + str(UTC())[:10]
runs = (1,1)    # (attempts to learn grammar per line, grammar tests per attempt)
if runs != (1,1): out_dir += '-multi'
kwargs = {
    'left_wall'     :   ''          ,
    'period'        :   False       ,
    'tmpath'        :   tmpath      , 
    'verbose'       :   'min'       ,
    'template_path' :   'poc-turtle',
    'linkage_limit' :   1000        ,
    'categories_generalization': 'off'}
lines = [
    [20, 'POC-English-Amb'    , 'MST-fixed-manually'             ,'LW','.', 'none'  ], 
    [21, 'POC-English-Amb'    , 'LG-English'                     ,'LW','.', 'none'  ], 
    [22, 'POC-English-Amb'    , 'R=6-Weight=6:R-mst-weight=+1:R' ,'LW','.', 'none'  ], 
    [23, 'POC-English-Amb'    , 'MST-fixed-manually'             , 0  , 0 , 'none'  ], 
    [24, 'POC-English-Amb'    , 'MST-fixed-manually'             , 0  , 0 , 'rules' ], 
    [25, 'POC-English-Amb'    , 'LG-English'                     , 0  , 0 , 'none'  ], 
    [26, 'POC-English-Amb'    , 'LG-English'                     , 0  , 0 , 'rules' ], 
    [27, 'POC-English-Amb'    , 'R=6-Weight=6:R-mst-weight=+1:R' , 0  , 0 , 'none'  ], 
    [28, 'POC-English-Amb'    , 'R=6-Weight=6:R-mst-weight=+1:R' , 0  , 0 , 'rules' ], 
    [29, 'POC-English-disAmb' , 'R=6-Weight=6:R-mst-weight=+1:R' , 0  , 0 , 'none'  ], 
    [30, 'POC-English-disAmb' , 'R=6-Weight=6:R-mst-weight=+1:R' , 0  , 0 , 'rules' ], 
    [31, 'POC-English-disAmb' , 'R=6-Weight=6:R-mst-weight=+1:R-adagram' , 0  , 0 , 'rules' ], 
    [32, 'POC-English-Amb'    , 'R=6-Weight=1-mst-weight=+1:R'   , 0  , 0 , 'none'  ], 
    [33, 'POC-English-disAmb' , 'R=6-Weight=1-mst-weight=+1:R'   , 0  , 0 , 'none'  ], 
    [34, 'POC-English-disAmb' , 'R=6-Weight=1-mst-weight=+1:R'   , 0  , 0 , 'rules' ], 
    [35, 'POC-English-disAmb' , 'R=6-Weight=1-mst-weight=+1:R-adagram'   , 0  , 0 , 'rules' ], 
    [36, 'POC-English-Amb'    , 'LG-ANY-all-parses'              , 0  , 0 , 'none'  ], 
    [37, 'POC-English-disAmb' , 'LG-ANY-all-parses'              , 0  , 0 , 'none'  ], 
    [38, 'POC-English-disAmb' , 'LG-ANY-all-parses'              , 0  , 0 , 'rules' ],
    [39, 'POC-English-disAmb' , 'LG-ANY-all-parses-adagram'      , 0  , 0 , 'rules' ]]
rp = module_path + '/data/POC-English-Amb/MST-fixed-manually/poc-english_ex-parses-gold.txt'
cps = (rp,rp)   # (test) corpus_paths for Amb and disAmb corpora
rps = (rp,rp)   # reference_paths for Amb and disAmb corpora

# %% [markdown]
# # POC-English-Amb, 5 datasets; ...-disAmb, 6 datasets
# ULL Project Plan ⇒ Parses ⇒ lines 20-39

# %% [markdown]
# ## Connectors-DRK-Connectors

# %%
# %%capture
kwargs['context'] = 1
kwargs['word_space'] = 'vectors'
kwargs['clustering'] = 'kmeans'
kwargs['grammar_rules'] = 1
average21, long21 = table_damb(lines, out_dir, cps, rps, runs, **kwargs)
table.extend(average21)
long_table.extend(long21)

# %%
display(html_table([header]+average21))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>20</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>27</td><td>70%</td><td>61%</td></tr><tr><td>21</td><td>POC-English-Amb</td><td>LG-English</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>25</td><td>84%</td><td>64%</td></tr><tr><td>22</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>27</td><td>90%</td><td>60%</td></tr><tr><td>23</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>28</td><td>73%</td><td>65%</td></tr><tr><td>25</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>28</td><td>85%</td><td>64%</td></tr><tr><td>27</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>28</td><td>85%</td><td>54%</td></tr><tr><td>29</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>27</td><td>86%</td><td>54%</td></tr><tr><td>32</td><td>POC-English-Amb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>17</td><td>88%</td><td>57%</td></tr><tr><td>33</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>20</td><td>89%</td><td>58%</td></tr><tr><td>36</td><td>POC-English-Amb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>19</td><td>90%</td><td>59%</td></tr><tr><td>37</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>29</td><td>86%</td><td>56%</td></tr></table>

# %% [markdown]
# ## Connectors-DRK-Disjuncts

# %%
# %%capture
kwargs['context'] = 1
kwargs['word_space'] = 'vectors'
kwargs['clustering'] = 'kmeans'
kwargs['grammar_rules'] = 2
average22, long22 = table_damb(lines, out_dir, cps, rps, runs, **kwargs)
table.extend(average22)
long_table.extend(long22)

# %%
display(html_table([header]+average22))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>20</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>22</td><td>0%</td><td>0%</td></tr><tr><td>21</td><td>POC-English-Amb</td><td>LG-English</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>30</td><td>0%</td><td>0%</td></tr><tr><td>22</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>31</td><td>73%</td><td>49%</td></tr><tr><td>23</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>27</td><td>44%</td><td>38%</td></tr><tr><td>24</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>25</td><td>40%</td><td>34%</td></tr><tr><td>25</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>28</td><td>28%</td><td>21%</td></tr><tr><td>26</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>25</td><td>45%</td><td>40%</td></tr><tr><td>27</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>23</td><td>90%</td><td>61%</td></tr><tr><td>28</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>24</td><td>75%</td><td>53%</td></tr><tr><td>29</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>29</td><td>69%</td><td>50%</td></tr><tr><td>30</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>25</td><td>81%</td><td>57%</td></tr><tr><td>31</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>24</td><td>84%</td><td>58%</td></tr><tr><td>32</td><td>POC-English-Amb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>20</td><td>83%</td><td>58%</td></tr><tr><td>33</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>20</td><td>75%</td><td>52%</td></tr><tr><td>34</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>19</td><td>75%</td><td>54%</td></tr><tr><td>35</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>21</td><td>86%</td><td>55%</td></tr><tr><td>36</td><td>POC-English-Amb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>19</td><td>84%</td><td>57%</td></tr><tr><td>37</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>27</td><td>95%</td><td>65%</td></tr><tr><td>38</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>23</td><td>95%</td><td>66%</td></tr><tr><td>39</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>20</td><td>89%</td><td>64%</td></tr></table>

# %% [markdown]
# ## Disjuncts-DRK-Disjuncts

# %%
# %%capture
kwargs['context'] = 2
kwargs['word_space'] = 'vectors'
kwargs['clustering'] = 'kmeans'
kwargs['grammar_rules'] = 2
average23, long23 = table_damb(lines, out_dir, cps, rps, runs, **kwargs)
table.extend(average23)
long_table.extend(long23)

# %%
display(html_table([header]+average23))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>20</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>24</td><td>8%</td><td>0%</td></tr><tr><td>21</td><td>POC-English-Amb</td><td>LG-English</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>3</td><td>92%</td><td>30%</td></tr><tr><td>22</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>23</td><td>83%</td><td>52%</td></tr><tr><td>23</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>25</td><td>38%</td><td>33%</td></tr><tr><td>24</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>19</td><td>39%</td><td>34%</td></tr><tr><td>25</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>22</td><td>18%</td><td>15%</td></tr><tr><td>26</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>18</td><td>23%</td><td>18%</td></tr><tr><td>27</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>5</td><td>95%</td><td>63%</td></tr><tr><td>28</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>5</td><td>94%</td><td>63%</td></tr><tr><td>29</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>29</td><td>65%</td><td>48%</td></tr><tr><td>30</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>30</td><td>67%</td><td>51%</td></tr><tr><td>31</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>3</td><td>99%</td><td>69%</td></tr><tr><td>32</td><td>POC-English-Amb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>12</td><td>81%</td><td>58%</td></tr><tr><td>33</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>13</td><td>73%</td><td>49%</td></tr><tr><td>34</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>11</td><td>85%</td><td>58%</td></tr><tr><td>35</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>25</td><td>70%</td><td>47%</td></tr><tr><td>36</td><td>POC-English-Amb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>4</td><td>99%</td><td>65%</td></tr><tr><td>37</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>12</td><td>96%</td><td>66%</td></tr><tr><td>38</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>11</td><td>99%</td><td>69%</td></tr><tr><td>39</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>13</td><td>86%</td><td>60%</td></tr></table>

# %% [markdown]
# ## Disjuncts-ILE-Disjuncts

# %%
# %%capture
kwargs['context'] = 2
kwargs['word_space'] = 'discrete'
kwargs['clustering'] = 'group'
kwargs['grammar_rules'] = 2
average24, long24 = table_damb(lines, out_dir, cps, rps, runs, **kwargs)
table.extend(average24)
long_table.extend(long24)

# %%
display(html_table([header]+average24))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>20</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>39</td><td>0%</td><td>0%</td></tr><tr><td>21</td><td>POC-English-Amb</td><td>LG-English</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>39</td><td>0%</td><td>0%</td></tr><tr><td>22</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>40</td><td>67%</td><td>45%</td></tr><tr><td>23</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>37</td><td>36%</td><td>32%</td></tr><tr><td>24</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>28</td><td>40%</td><td>34%</td></tr><tr><td>25</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>37</td><td>18%</td><td>14%</td></tr><tr><td>26</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>31</td><td>18%</td><td>15%</td></tr><tr><td>27</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>38</td><td>61%</td><td>44%</td></tr><tr><td>28</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>34</td><td>75%</td><td>53%</td></tr><tr><td>29</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>39</td><td>63%</td><td>46%</td></tr><tr><td>30</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>36</td><td>67%</td><td>51%</td></tr><tr><td>31</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>36</td><td>70%</td><td>52%</td></tr><tr><td>32</td><td>POC-English-Amb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>39</td><td>53%</td><td>42%</td></tr><tr><td>33</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>41</td><td>47%</td><td>38%</td></tr><tr><td>34</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>37</td><td>52%</td><td>42%</td></tr><tr><td>35</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>39</td><td>52%</td><td>41%</td></tr><tr><td>36</td><td>POC-English-Amb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>38</td><td>74%</td><td>52%</td></tr><tr><td>37</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>39</td><td>89%</td><td>61%</td></tr><tr><td>38</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>33</td><td>95%</td><td>67%</td></tr><tr><td>39</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>37</td><td>70%</td><td>56%</td></tr></table>

# %% [markdown]
# # All tests (all entries for multi-test `runs > (1.1)`)

# %%
display(html_table([header]+long_table))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>20</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 27 </td><td>70%</td><td>61%</td></tr><tr><td>21</td><td>POC-English-Amb</td><td>LG-English</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 25 </td><td>84%</td><td>64%</td></tr><tr><td>22</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 27 </td><td>90%</td><td>60%</td></tr><tr><td>23</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 28 </td><td>73%</td><td>65%</td></tr><tr><td>25</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 28 </td><td>85%</td><td>64%</td></tr><tr><td>27</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 28 </td><td>85%</td><td>54%</td></tr><tr><td>29</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 27 </td><td>86%</td><td>54%</td></tr><tr><td>32</td><td>POC-English-Amb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 17 </td><td>88%</td><td>57%</td></tr><tr><td>33</td><td>POC-English-disAmb</td><td>R=6-Weight=1-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 20 </td><td>89%</td><td>58%</td></tr><tr><td>36</td><td>POC-English-Amb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 19 </td><td>90%</td><td>59%</td></tr><tr><td>37</td><td>POC-English-disAmb</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 29 </td><td>86%</td><td>56%</td></tr><tr><td>20</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 22 </td><td>0%</td><td>0%</td></tr><tr><td>21</td><td>POC-English-Amb</td><td>LG-English</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 30 </td><td>0%</td><td>0%</td></tr><tr><td>22</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 31 </td><td>73%</td><td>49%</td></tr><tr><td>23</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 27 </td><td>44%</td><td>38%</td></tr><tr><td>24</td><td>POC-English-Amb</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 25 </td><td>40%</td><td>34%</td></tr><tr><td>25</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 28 </td><td>28%</td><td>21%</td></tr><tr><td>26</td><td>POC-English-Amb</td><td>LG-English</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 25 </td><td>45%</td><td>40%</td></tr><tr><td>27</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 23 </td><td>90%</td><td>61%</td></tr><tr><td>28</td><td>POC-English-Amb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 24 </td><td>75%</td><td>53%</td></tr><tr><td>29</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 29 </td><td>69%</td><td>50%</td></tr><tr><td>30</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 25 </td><td>81%</td><td>57%</td></tr><tr><td>31</td><td>POC-English-disAmb</td><td>R=6-Weight=6:R-mst-weight=+1:R-adagram</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 24 </td><td>84%</td><td>58%</td></tr><tr><td>32</td><td>POC-English-Amb</td><td>R=6 ...

# %%
from write_files import list2file
print(UTC(), ':: finished, elapsed', str(round((time.time()-start)/60, 1)), 'min')
table_str = list2file(table, out_dir+'/short_table.txt')
if runs == (1,1):
    print('Results saved to', out_dir + '/short_table.txt')
else:
    long_table_str = list2file(long_table, out_dir+'/long_table.txt')
    print('Average results saved to', out_dir + '/short_table.txt\n'
          'Detailed results for every run saved to', out_dir + '/long_table.txt')
# Out:
# 2018-07-27 15:26:06 UTC :: finished, elapsed 2.5 min
# Results saved to /home/obaskov/language-learning/output/POC-English-Amb-2018-07-27/short_table.txt
