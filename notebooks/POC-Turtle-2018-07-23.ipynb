# %% [markdown]
# # POC-Turtle tests `2018-07-23`
#
# New (2018-07-05) Grammar Tester, server `94.130.238.118`
# **Data and directory names updated 2018-07-23**, not compatible with previous data
#
# Each line is calculated 1x, parsing metrics tested 1x for each calculation.
# The calculation table is shared as 'short_table.txt' in data folder
# [http://langlearn.singularitynet.io/data/clustering_2018/POC-Turtle-2018-07-23/](http://langlearn.singularitynet.io/data/clustering_2018/POC-Turtle-2018-07-23/)
# This notebook is shared as static html via
# [http://langlearn.singularitynet.io/data/clustering_2018/html/POC-Turtle-2018-07-23.html](http://langlearn.singularitynet.io/data/clustering_2018/html/POC-Turtle-2018-07-23.html)
# Results consistency test is shared via
# [http://langlearn.singularitynet.io/data/clustering_2018/html/POC-Turtle-2018-07-23-multi.html](http://langlearn.singularitynet.io/data/clustering_2018/html/POC-Turtle-2018-07-23-multi.html)

# %% [markdown]
# ## Basic settings

# %%
import os, sys, time
from IPython.display import display
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path: sys.path.append(module_path)
src_path = module_path + '/src'
if os.path.exists(src_path) and src_path not in sys.path: sys.path.append(src_path)
from src.utl.utl import UTC
from src.utl.read_files import check_dir
from src.utl.widgets import html_table
from src.utl.pqa_table import table_cds
tmpath = module_path + '/tmp/'
if check_dir(tmpath, True, 'none'):
    table = []
    long_table = []
    header = ['Line','Corpus','Parsing','LW','"."','Generalization','Space','Rules','PA','PQ']
    start = time.time()
    print(UTC(), ':: module_path =', module_path)
else: print(UTC(), ':: could not create temporary files directory', tmpath)
# Out:
# 2018-07-23 18:04:01 UTC :: module_path = /home/obaskov/language-learning

# %% [markdown]
# ## Grammar Learner corpus-specific parameters

# %%
corpus = 'POC-Turtle'
out_dir = module_path + '/output/'+ corpus + '-' + str(UTC())[:10]
runs = (1,1)    # (attempts to learn grammar per line, grammar tests per attempt)
if runs != (1,1): out_dir += '-multi'
kwargs = {
    'left_wall'     :   ''          ,
    'period'        :   False       ,
    'tmpath'        :   tmpath      , 
    'verbose'       :   'min'       ,
    'template_path' :   'poc-turtle',
    'linkage_limit' :   100         ,
    'categories_generalization': 'off' }
lines = [
    [4, 'POC-Turtle'    , 'MST-fixed-manually'              ,'LW','.', 'none'  ],
    [4, 'POC-Turtle'    , 'MST-fixed-manually'              , 0  , 0 , 'none'  ],
    [4, 'POC-Turtle'    , 'MST-fixed-manually'              , 0  , 0 , 'rules' ],
    [5, 'POC-Turtle'    , 'R=6-Weight=6:R-mst-weight=+1:R'  ,'LW','.', 'none'  ],
    [5, 'POC-Turtle'    , 'R=6-Weight=6:R-mst-weight=+1:R'  , 0  , 0 , 'none'  ],
    [5, 'POC-Turtle'    , 'R=6-Weight=6:R-mst-weight=+1:R'  , 0  , 0 , 'rules' ],
    [6, 'POC-Turtle'    , 'R=6-Weight=1-no-mst-weighting'   ,'LW','.', 'none'  ], 
    [6, 'POC-Turtle'    , 'R=6-Weight=1-no-mst-weighting'   , 0  , 0 , 'none'  ],
    [6, 'POC-Turtle'    , 'R=6-Weight=1-no-mst-weighting'   , 0  , 0 , 'rules' ],
    [7, 'POC-Turtle'    , 'LG-ANY-all-parses'               ,'LW','.', 'none'  ],
    [7, 'POC-Turtle'    , 'LG-ANY-all-parses'               , 0  , 0 , 'none'  ],
    [7, 'POC-Turtle'    , 'LG-ANY-all-parses'               , 0  , 0 , 'rules' ]]
# cp,rp :: (test) corpus_path and reference_path
cp = module_path + '/data/POC-Turtle/poc-turtle-corpus.txt'
rp = module_path + '/data/POC-Turtle/MST-fixed-manually/poc-turtle-parses-gold.txt'
# cp = rp?  # July 2018 Grammar Tester option

# %% [markdown]
# # ULL Project Plan ⇒ Parses ⇒ lines 5-7

# %% [markdown]
# ## Connectors-DRK-Connectors

# %%
# %%capture
kwargs['context'] = 1
kwargs['word_space'] = 'vectors'
kwargs['clustering'] = 'kmeans'
kwargs['grammar_rules'] = 1
average21, long21 = table_cds(lines, out_dir, cp, rp, runs, **kwargs)
table.extend(average21)
long_table.extend(long21)

# %%
display(html_table([header]+average21))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>3</td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>3</td><td>100%</td><td>100%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>8</td><td>75%</td><td>33%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>7</td><td>67%</td><td>0%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td>4</td><td>100%</td><td>100%</td></tr></table>

# %% [markdown]
# ## Connectors-DRK-Disjuncts

# %%
# %%capture
kwargs['context'] = 1
kwargs['word_space'] = 'vectors'
kwargs['clustering'] = 'kmeans'
kwargs['grammar_rules'] = 2
average22, long22 = table_cds(lines, out_dir, cp, rp, runs, **kwargs)
table.extend(average22)
long_table.extend(long22)

# %%
display(html_table([header]+average22))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>4</td><td>44%</td><td>33%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>3</td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>3</td><td>89%</td><td>83%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>3</td><td>100%</td><td>92%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>3</td><td>100%</td><td>92%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>8</td><td>0%</td><td>0%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>7</td><td>0%</td><td>0%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>5</td><td>33%</td><td>17%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td>4</td><td>44%</td><td>33%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td>3</td><td>100%</td><td>100%</td></tr></table>

# %% [markdown]
# ## Disjuncts-DRK-Disjuncts

# %%
# %%capture
kwargs['context'] = 2
kwargs['word_space'] = 'vectors'
kwargs['clustering'] = 'kmeans'
kwargs['grammar_rules'] = 2
average23, long23 = table_cds(lines, out_dir, cp, rp, runs, **kwargs)
table.extend(average23)
long_table.extend(long23)

# %%
display(html_table([header]+average23))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>6</td><td>0%</td><td>0%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>4</td><td>83%</td><td>75%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>4</td><td>100%</td><td>92%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>4</td><td>100%</td><td>92%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>3</td><td>75%</td><td>62%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td>5</td><td>42%</td><td>25%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td>4</td><td>92%</td><td>92%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td>3</td><td>92%</td><td>92%</td></tr></table>

# %% [markdown]
# ## Disjuncts-ILE-Disjuncts

# %%
# %%capture
kwargs['context'] = 2
kwargs['word_space'] = 'discrete'
kwargs['clustering'] = 'group'
kwargs['grammar_rules'] = 2
average24, long24 = table_cds(lines, out_dir, cp, rp, runs, **kwargs)
table.extend(average24)
long_table.extend(long24)

# %%
display(html_table([header]+average24))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>8</td><td>0%</td><td>0%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>6</td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>4</td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>10</td><td>0%</td><td>0%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>8</td><td>83%</td><td>83%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>6</td><td>100%</td><td>92%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>13</td><td>0%</td><td>0%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>11</td><td>0%</td><td>0%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>9</td><td>33%</td><td>17%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td>LW</td><td> + </td><td>none</td><td>dILEd</td><td>10</td><td>0%</td><td>0%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>dILEd</td><td>8</td><td>92%</td><td>92%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>dILEd</td><td>5</td><td>92%</td><td>92%</td></tr></table>

# %% [markdown]
# # All tests (all entries for multi-test `runs > (1.1)`)

# %%
display(html_table([header]+long_table))
# Out:
# <table><tr><td>Line</td><td>Corpus</td><td>Parsing</td><td>LW</td><td>"."</td><td>Generalization</td><td>Space</td><td>Rules</td><td>PA</td><td>PQ</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 3 </td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 3 </td><td>100%</td><td>100%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 8 </td><td>75%</td><td>33%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 7 </td><td>67%</td><td>0%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td>LW</td><td> + </td><td>none</td><td>cDRKc</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKc</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 4 </td><td>44%</td><td>33%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 3 </td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 3 </td><td>89%</td><td>83%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 3 </td><td>100%</td><td>92%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 3 </td><td>100%</td><td>92%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 8 </td><td>0%</td><td>0%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 7 </td><td>0%</td><td>0%</td></tr><tr><td>6</td><td>POC-Turtle</td><td>R=6-Weight=1-no-mst-weighting</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 5 </td><td>33%</td><td>17%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td>LW</td><td> + </td><td>none</td><td>cDRKd</td><td> 4 </td><td>44%</td><td>33%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>none</td><td>cDRKd</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>7</td><td>POC-Turtle</td><td>LG-ANY-all-parses</td><td> -- </td><td> -- </td><td>rules</td><td>cDRKd</td><td> 3 </td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td> 6 </td><td>0%</td><td>0%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>none</td><td>dDRKd</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>4</td><td>POC-Turtle</td><td>MST-fixed-manually</td><td> -- </td><td> -- </td><td>rules</td><td>dDRKd</td><td> 4 </td><td>100%</td><td>100%</td></tr><tr><td>5</td><td>POC-Turtle</td><td>R=6-Weight=6:R-mst-weight=+1:R</td><td>LW</td><td> + </td><td>none</td><td>dDRKd</td><td> 4 </td><td>83%</td><td>75%</td></tr><tr><td>5</td><td>POC-Turtle</td ...

# %%
from src.utl.write_files import list2file
print(UTC(), ':: finished, elapsed', str(round((time.time()-start)/60, 1)), 'min')
table_str = list2file(table, out_dir+'/short_table.txt')
if runs == (1,1):
    print('Results saved to', out_dir + '/short_table.txt')
else:
    long_table_str = list2file(long_table, out_dir+'/long_table.txt')
    print('Average results saved to', out_dir + '/short_table.txt\n'
          'Detailed results for every run saved to', out_dir + '/long_table.txt')
# Out:
# 2018-07-23 18:04:12 UTC :: finished, elapsed 0.2 min
# Results saved to /home/obaskov/language-learning/output/POC-Turtle-2018-07-23/short_table.txt
